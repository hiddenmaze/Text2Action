# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import model.struct_GAN as structure
import model.trainer_GAN as trainer
import numpy as np
import tensorflow as tf
import scipy.io as scio
from util.my_functions import load_metadata

# %%
metadata_path = '../data/metadata.npz'

train_action, train_script, train_length, sentence_steps = load_metadata(metadata_path)

# %%
init_pose = scio.loadmat('../data/mean_pose.mat')['mean_vector']

num_data_train = train_action.shape[0]

dim_sentence = 300
dim_char_enc = 300
dim_gen = 300
dim_dis = 300
batch_size = 32

action_steps = 32
dim_random = 10

seq2seq_model_dir = '../seq2seq_model/model.ckpt-500'
dis_model_dir = ''
gan_model_dir = '../gan_model'

model = structure.GAN_model(sentence_steps=sentence_steps,
                            action_steps=action_steps,
                            dim_sentence=dim_sentence,
                            dim_char_enc=dim_char_enc,
                            dim_gen=dim_gen,
                            dim_dis=dim_dis)
train_module = trainer.GAN_trainer(gan_model=model,
                              train_script=train_script,
                              train_script_len=train_length,
                              train_action=train_action,
                              init_pose=init_pose,
                              num_data=num_data_train,
                              batch_size=batch_size,
                              gan_model_dir=gan_model_dir,
                              seq2seq_model_dir=seq2seq_model_dir,
                              dis_model_dir=dis_model_dir,
                              sentence_steps=sentence_steps,
                              action_steps=action_steps,
                              dim_sentence=dim_sentence,
                              dim_char_enc=dim_char_enc,
                              dim_gen=dim_gen,
                              dim_random=dim_random,
                              restore=0,
                              restore_path='',
                              restore_step=0
                              )
train_module.train()
# Out:
# INFO:tensorflow:Restoring parameters from ../seq2seq_model/model.ckpt-500
# INFO:tensorflow:Restoring parameters from ../gan_model/model.ckpt-200
# Restored ../gan_model/model.ckpt-200
# ('200', ': batch_gen_loss : 0.821368, dis_loss :1.27066')
# ('200', ': batch_gen_loss : 0.764658, dis_loss :1.36507')
# ('200', ': batch_gen_loss : 0.782256, dis_loss :1.39231')
# ('200', ': batch_gen_loss : 0.801851, dis_loss :1.34734')
# ('200', ': batch_gen_loss : 0.787372, dis_loss :1.21855')
# ('200', ': batch_gen_loss : 0.754949, dis_loss :1.332')
# ('200', ': batch_gen_loss : 0.726551, dis_loss :1.30882')
# ('200', ': batch_gen_loss : 0.78705, dis_loss :1.28261')
# ('200', ': batch_gen_loss : 0.768348, dis_loss :1.23588')
# ('200', ': batch_gen_loss : 0.79202, dis_loss :1.28927')
# ('201', ': batch_gen_loss : 0.777555, dis_loss :1.31183')
# ('201', ': batch_gen_loss : 0.776672, dis_loss :1.34267')
# ('201', ': batch_gen_loss : 0.713443, dis_loss :1.39848')
# ('201', ': batch_gen_loss : 0.784955, dis_loss :1.18201')
# ('201', ': batch_gen_loss : 0.727606, dis_loss :1.38558')
# ('201', ': batch_gen_loss : 0.752934, dis_loss :1.2875')
# ('201', ': batch_gen_loss : 0.743633, dis_loss :1.33689')
# ('201', ': batch_gen_loss : 0.724608, dis_loss :1.32382')
# ('201', ': batch_gen_loss : 0.769718, dis_loss :1.35824')
# ('201', ': batch_gen_loss : 0.761908, dis_loss :1.26052')
# ('202', ': batch_gen_loss : 0.785712, dis_loss :1.2027')
# ('202', ': batch_gen_loss : 0.790222, dis_loss :1.32099')
# ('202', ': batch_gen_loss : 0.825466, dis_loss :1.27354')
# ('202', ': batch_gen_loss : 0.762168, dis_loss :1.23371')
# ('202', ': batch_gen_loss : 0.770883, dis_loss :1.28428')
# ('202', ': batch_gen_loss : 0.830239, dis_loss :1.19868')
# ('202', ': batch_gen_loss : 0.802266, dis_loss :1.24401')
# ('202', ': batch_gen_loss : 0.825051, dis_loss :1.20856')
# ('202', ': batch_gen_loss : 0.858703, dis_loss :1.22643')
# ('202', ': batch_gen_loss : 0.828399, dis_loss :1.27499')
# ('203', ': batch_gen_loss : 0.836689, dis_loss :1.18223')
# ('203', ': batch_gen_loss : 0.782752, dis_loss :1.25421')
# ('203', ': batch_gen_loss : 0.803932, dis_loss :1.18499')
# ('203', ': batch_gen_loss : 0.830801, dis_loss :1.27077')
# ('203', ': batch_gen_loss : 0.82627, dis_loss :1.16745')
# ('203', ': batch_gen_loss : 0.834655, dis_loss :1.30222')
# ('203', ': batch_gen_loss : 0.835058, dis_loss :1.33644')
# ('203', ': batch_gen_loss : 0.883849, dis_loss :1.30466')
# ('203', ': batch_gen_loss : 0.802106, dis_loss :1.22994')
# ('203', ': batch_gen_loss : 0.733285, dis_loss :1.27764')
# ('204', ': batch_gen_loss : 0.800931, dis_loss :1.28128')
# ('204', ': batch_gen_loss : 0.86482, dis_loss :1.23648')
# ('204', ': batch_gen_loss : 0.939691, dis_loss :1.21677')
# ('204', ': batch_gen_loss : 0.815027, dis_loss :1.21288')
# ('204', ': batch_gen_loss : 0.864773, dis_loss :1.29833')
# ('204', ': batch_gen_loss : 0.932703, dis_loss :1.14429')
# ('204', ': batch_gen_loss : 0.826406, dis_loss :1.24569')
# ('204', ': batch_gen_loss : 0.757168, dis_loss :1.29205')
# ('204', ': batch_gen_loss : 0.883787, dis_loss :1.22176')
# ('204', ': batch_gen_loss : 0.84905, dis_loss :1.19091')
# Model saved in file : ../gan_model/model.ckpt-205
# ('205', ': batch_gen_loss : 0.825132, dis_loss :1.34814')
# ('205', ': batch_gen_loss : 0.827693, dis_loss :1.26335')
# ('205', ': batch_gen_loss : 0.832653, dis_loss :1.18763')
# ('205', ': batch_gen_loss : 0.840927, dis_loss :1.27563')
# ('205', ': batch_gen_loss : 0.872317, dis_loss :1.24555')
# ('205', ': batch_gen_loss : 0.800804, dis_loss :1.3173')
# ('205', ': batch_gen_loss : 0.75472, dis_loss :1.36856')
# ('205', ': batch_gen_loss : 0.637292, dis_loss :1.35557')
# ('205', ': batch_gen_loss : 0.784611, dis_loss :1.21265')
# ('205', ': batch_gen_loss : 0.814107, dis_loss :1.21108')
# ('206', ': batch_gen_loss : 0.831877, dis_loss :1.28606')
# ('206', ': batch_gen_loss : 0.769211, dis_loss :1.32942')
# ('206', ': batch_gen_loss : 0.956632, dis_loss :1.25968')
# ('206', ': batch_gen_loss : 0.857703, dis_loss :1.2623')
# ('206', ': batch_gen_loss : 0.721757, dis_loss :1.4174')
# ('206', ': batch_gen_loss : 0.820907, dis_loss :1.30329')
# ('206', ': batch_gen_loss : 0.784187, dis_loss :1.29035')
# ('206', ': batch_gen_loss : 0.797942, dis_loss :1.26215')
# ('206', ': batch_gen_loss : 0.813653, dis_loss :1.27575')
# ('206', ': batch_gen_loss : 0.826594, dis_loss :1.22284')
# ('207', ': batch_gen_loss : 0.729704, dis_loss :1.30742')
# ('207', ': batch_gen_loss : 0.81144, dis_loss :1.25395')
# ('207', ': batch_gen_loss : 0.811546, dis_loss :1.26154')
# ('207', ': batch_gen_loss : 0.80532, dis_loss :1.28758')
# ('207', ': batch_gen_loss : 0.836168, dis_loss :1.27248')
# ('207', ': batch_gen_loss : 0.775438, dis_loss :1.29535')
# ('207', ': batch_gen_loss : 0.776403, dis_loss :1.25972')
# ('207', ': batch_gen_loss : 0.710414, dis_loss :1.37522')
# ('207', ': batch_gen_loss : 0.785889, dis_loss :1.34771')
# ('207', ': batch_gen_loss : 0.783442, dis_loss :1.26504')
# ('208', ': batch_gen_loss : 0.816701, dis_loss :1.23394')
# ('208', ': batch_gen_loss : 0.802906, dis_loss :1.24172')
# ('208', ': batch_gen_loss : 0.792507, dis_loss :1.25959')
# ('208', ': batch_gen_loss : 0.857715, dis_loss :1.20552')
# ('208', ': batch_gen_loss : 0.85746, dis_loss :1.28548')
# ('208', ': batch_gen_loss : 0.86583, dis_loss :1.23618')
# ('208', ': batch_gen_loss : 0.839348, dis_loss :1.17497')
# ('208', ': batch_gen_loss : 0.86671, dis_loss :1.20146')
# ('208', ': batch_gen_loss : 0.823596, dis_loss :1.33387')
# ('208', ': batch_gen_loss : 0.819872, dis_loss :1.31347')
# ('209', ': batch_gen_loss : 0.810785, dis_loss :1.32691')
# ('209', ': batch_gen_loss : 0.837962, dis_loss :1.15344')
# ('209', ': batch_gen_loss : 0.860057, dis_loss :1.25052')
# ('209', ': batch_gen_loss : 0.834061, dis_loss :1.23325')
# ('209', ': batch_gen_loss : 0.78595, dis_loss :1.22237')
# ('209', ': batch_gen_loss : 0.813617, dis_loss :1.29433')
# ('209', ': batch_gen_loss : 0.808339, dis_loss :1.33616')
# ('209', ': batch_gen_loss : 0.751532, dis_loss :1.24322')
# ('209', ': batch_gen_loss : 0.766707, dis_loss :1.3515')
# ('209', ': batch_gen_loss : 0.878976, dis_loss :1.1742')
# Model saved in file : ../gan_model/model.ckpt-210
# ('210', ': batch_gen_loss : 0.903374, dis_loss :1.32402')
# ('210', ': batch_gen_loss : 0.837858, dis_loss :1.22068')
# ('210', ': batch_gen_loss : 0.799328, dis_loss :1.27739')
# ('210', ': batch_gen_loss : 0.826221, dis_loss :1.31963')
# ('210', ': batch_gen_loss : 0.829334, dis_loss :1.33274')
# ('210', ': batch_gen_loss : 0.765238, dis_loss :1.36076')
# ('210', ': batch_gen_loss : 0.835939, dis_loss :1.33713')
# ('210', ': batch_gen_loss : 0.760701, dis_loss :1.29245')
# ('210', ': batch_gen_loss : 0.773579, dis_loss :1.3711')
# ('210', ': batch_gen_loss : 0.783885, dis_loss :1.41907')
# ('211', ': batch_gen_loss : 0.790948, dis_loss :1.26053')
# ('211', ': batch_gen_loss : 0.841072, dis_loss :1.28957')
# ('211', ': batch_gen_loss : 0.902451, dis_loss :1.14928')
# ('211', ': batch_gen_loss : 0.879148, dis_loss :1.27068')
# ('211', ': batch_gen_loss : 0.994036, dis_loss :1.23425')
# ('211', ': batch_gen_loss : 0.886337, dis_loss :1.20483')
# ('211', ': batch_gen_loss : 0.788328, dis_loss :1.15592')
# ('211', ': batch_gen_loss : 0.867799, dis_loss :1.15444')
# ('211', ': batch_gen_loss : 0.862843, dis_loss :1.29779')
# ('211', ': batch_gen_loss : 0.811527, dis_loss :1.23809')
# ('212', ': batch_gen_loss : 0.875395, dis_loss :1.16786')
# ('212', ': batch_gen_loss : 0.870698, dis_loss :1.21203')
# ('212', ': batch_gen_loss : 0.843692, dis_loss :1.12582')
# ('212', ': batch_gen_loss : 0.827698, dis_loss :1.19941')
# ('212', ': batch_gen_loss : 0.842846, dis_loss :1.39127')
# ('212', ': batch_gen_loss : 0.929428, dis_loss :1.12905')
# ('212', ': batch_gen_loss : 0.798777, dis_loss :1.38908')
# ('212', ': batch_gen_loss : 0.838833, dis_loss :1.27635')
# ('212', ': batch_gen_loss : 0.859039, dis_loss :1.20844')
# ('212', ': batch_gen_loss : 0.855036, dis_loss :1.20022')
# ('213', ': batch_gen_loss : 0.873629, dis_loss :1.1598')
# ('213', ': batch_gen_loss : 0.897066, dis_loss :1.25173')
# ('213', ': batch_gen_loss : 0.942935, dis_loss :1.20422')
# ('213', ': batch_gen_loss : 0.827341, dis_loss :1.25505')
# ('213', ': batch_gen_loss : 0.814528, dis_loss :1.13333')
# ('213', ': batch_gen_loss : 0.898307, dis_loss :1.13331')
# ('213', ': batch_gen_loss : 0.790565, dis_loss :1.29744')
# ('213', ': batch_gen_loss : 0.818829, dis_loss :1.19693')
# ('213', ': batch_gen_loss : 0.808172, dis_loss :1.22743')
# ('213', ': batch_gen_loss : 0.878639, dis_loss :1.20792')
# ('214', ': batch_gen_loss : 0.884282, dis_loss :1.24428')
# ('214', ': batch_gen_loss : 0.825865, dis_loss :1.33595')
# ('214', ': batch_gen_loss : 0.941567, dis_loss :1.21876')
# ('214', ': batch_gen_loss : 0.804895, dis_loss :1.2391')
# ('214', ': batch_gen_loss : 0.876384, dis_loss :1.13466')
# ('214', ': batch_gen_loss : 0.84663, dis_loss :1.25235')
# ('214', ': batch_gen_loss : 0.909959, dis_loss :1.18269')
# ('214', ': batch_gen_loss : 0.84565, dis_loss :1.27873')
# ('214', ': batch_gen_loss : 0.806833, dis_loss :1.17607')
# ('214', ': batch_gen_loss : 0.927935, dis_loss :1.26049')
# Model saved in file : ../gan_model/model.ckpt-215
# ('215', ': batch_gen_loss : 0.83534, dis_loss :1.18998')
# ('215', ': batch_gen_loss : 0.838724, dis_loss :1.22146')
# ('215', ': batch_gen_loss : 0.794932, dis_loss :1.27427')
# ('215', ': batch_gen_loss : 0.849407, dis_loss :1.20238')
# ('215', ': batch_gen_loss : 0.871549, dis_loss :1.27572')
# ('215', ': batch_gen_loss : 0.883256, dis_loss :1.17513')
# ('215', ': batch_gen_loss : 0.921091, dis_loss :1.1652')
# ('215', ': batch_gen_loss : 0.80267, dis_loss :1.20307')
# ('215', ': batch_gen_loss : 0.836479, dis_loss :1.26712')
# ('215', ': batch_gen_loss : 0.879854, dis_loss :1.27193')
# ('216', ': batch_gen_loss : 0.803218, dis_loss :1.26692')
# ('216', ': batch_gen_loss : 0.776856, dis_loss :1.18786')
# ('216', ': batch_gen_loss : 0.815831, dis_loss :1.24039')
# ('216', ': batch_gen_loss : 0.799627, dis_loss :1.33263')
# ('216', ': batch_gen_loss : 0.777442, dis_loss :1.33564')
# ('216', ': batch_gen_loss : 0.827524, dis_loss :1.28886')
# ('216', ': batch_gen_loss : 0.883968, dis_loss :1.1413')
# ('216', ': batch_gen_loss : 0.843944, dis_loss :1.27175')
# ('216', ': batch_gen_loss : 0.858732, dis_loss :1.19213')
# ('216', ': batch_gen_loss : 0.824979, dis_loss :1.3618')
# ('217', ': batch_gen_loss : 0.771803, dis_loss :1.33133')
# ('217', ': batch_gen_loss : 0.83529, dis_loss :1.21751')
# ('217', ': batch_gen_loss : 0.840299, dis_loss :1.11644')
# ('217', ': batch_gen_loss : 0.766899, dis_loss :1.24982')
# ('217', ': batch_gen_loss : 0.890424, dis_loss :1.21198')
# ('217', ': batch_gen_loss : 0.906086, dis_loss :1.08428')
# ('217', ': batch_gen_loss : 0.864416, dis_loss :1.23134')
# ('217', ': batch_gen_loss : 0.818192, dis_loss :1.24351')
# ('217', ': batch_gen_loss : 0.866989, dis_loss :1.21862')
# ('217', ': batch_gen_loss : 0.783969, dis_loss :1.30035')
# ('218', ': batch_gen_loss : 0.961427, dis_loss :1.2019')
# ('218', ': batch_gen_loss : 0.873496, dis_loss :1.33024')
# ('218', ': batch_gen_loss : 0.803359, dis_loss :1.27647')
# ('218', ': batch_gen_loss : 0.758508, dis_loss :1.35668')
# ('218', ': batch_gen_loss : 0.887737, dis_loss :1.26294')
# ('218', ': batch_gen_loss : 0.828145, dis_loss :1.24844')
# ('218', ': batch_gen_loss : 0.77687, dis_loss :1.29115')
# ('218', ': batch_gen_loss : 0.804659, dis_loss :1.34656')
# ('218', ': batch_gen_loss : 0.836616, dis_loss :1.23434')
# ('218', ': batch_gen_loss : 0.852003, dis_loss :1.19003')
# ('219', ': batch_gen_loss : 0.854583, dis_loss :1.21352')
# ('219', ': batch_gen_loss : 0.780545, dis_loss :1.31835')
# ('219', ': batch_gen_loss : 0.856128, dis_loss :1.26836')
# ('219', ': batch_gen_loss : 0.833684, dis_loss :1.26428')
# ('219', ': batch_gen_loss : 0.783222, dis_loss :1.35107')
# ('219', ': batch_gen_loss : 0.74079, dis_loss :1.39421')
# ('219', ': batch_gen_loss : 0.717002, dis_loss :1.37803')
# ('219', ': batch_gen_loss : 0.78888, dis_loss :1.27467')
# ('219', ': batch_gen_loss : 0.889913, dis_loss :1.30656')
# ('219', ': batch_gen_loss : 0.842572, dis_loss :1.16293')
# Model saved in file : ../gan_model/model.ckpt-220
# ('220', ': batch_gen_loss : 0.79896, dis_loss :1.29412')
# ('220', ': batch_gen_loss : 0.836423, dis_loss :1.38535')
# ('220', ': batch_gen_loss : 0.799731, dis_loss :1.33562')
# ('220', ': batch_gen_loss : 0.871797, dis_loss :1.18269')
# ('220', ': batch_gen_loss : 0.814058, dis_loss :1.26788')
# ('220', ': batch_gen_loss : 0.880356, dis_loss :1.23995')
# ('220', ': batch_gen_loss : 0.92974, dis_loss :1.11535')
# ('220', ': batch_gen_loss : 0.83778, dis_loss :1.25549')
# ('220', ': batch_gen_loss : 0.757704, dis_loss :1.28362')
# ('220', ': batch_gen_loss : 0.875225, dis_loss :1.28269')
# ('221', ': batch_gen_loss : 0.826454, dis_loss :1.23147')
# ('221', ': batch_gen_loss : 0.836534, dis_loss :1.22829')
# ('221', ': batch_gen_loss : 0.82563, dis_loss :1.35736')
# ('221', ': batch_gen_loss : 0.808517, dis_loss :1.09528')
# ('221', ': batch_gen_loss : 0.85394, dis_loss :1.18557')
# ('221', ': batch_gen_loss : 0.928774, dis_loss :1.11846')
# ('221', ': batch_gen_loss : 0.867069, dis_loss :1.17871')
# ('221', ': batch_gen_loss : 0.778253, dis_loss :1.39785')
# ('221', ': batch_gen_loss : 0.939802, dis_loss :1.29445')
# ('221', ': batch_gen_loss : 0.951967, dis_loss :1.10663')
# ('222', ': batch_gen_loss : 0.806388, dis_loss :1.30954')
# ('222', ': batch_gen_loss : 0.816854, dis_loss :1.22541')
# ('222', ': batch_gen_loss : 0.927902, dis_loss :1.12377')
# ('222', ': batch_gen_loss : 0.801095, dis_loss :1.2752')
# ('222', ': batch_gen_loss : 0.990676, dis_loss :1.11235')
# ('222', ': batch_gen_loss : 0.854459, dis_loss :1.20764')
# ('222', ': batch_gen_loss : 0.890694, dis_loss :1.2803')
# ('222', ': batch_gen_loss : 0.837992, dis_loss :1.26733')
# ('222', ': batch_gen_loss : 0.94875, dis_loss :1.14322')
# ('222', ': batch_gen_loss : 1.04343, dis_loss :1.04007')
# ('223', ': batch_gen_loss : 0.964563, dis_loss :1.06889')
# ('223', ': batch_gen_loss : 1.07629, dis_loss :1.06062')
# ('223', ': batch_gen_loss : 0.938589, dis_loss :1.10473')
# ('223', ': batch_gen_loss : 0.963872, dis_loss :1.158')
# ('223', ': batch_gen_loss : 0.844141, dis_loss :1.23529')
# ('223', ': batch_gen_loss : 0.922902, dis_loss :1.17637')
# ('223', ': batch_gen_loss : 0.92662, dis_loss :1.17648')
# ('223', ': batch_gen_loss : 0.892682, dis_loss :1.11111')
# ('223', ': batch_gen_loss : 1.03956, dis_loss :1.0876')
# ('223', ': batch_gen_loss : 0.944438, dis_loss :1.15421')
# ('224', ': batch_gen_loss : 1.01476, dis_loss :1.02887')
# ('224', ': batch_gen_loss : 0.995788, dis_loss :1.15252')
# ('224', ': batch_gen_loss : 1.00989, dis_loss :1.08667')
# ('224', ': batch_gen_loss : 1.02099, dis_loss :1.24868')
# ('224', ': batch_gen_loss : 0.96208, dis_loss :1.04054')
# ('224', ': batch_gen_loss : 1.02089, dis_loss :1.09278')
# ('224', ': batch_gen_loss : 1.02674, dis_loss :1.17968')
# ('224', ': batch_gen_loss : 1.03979, dis_loss :1.12573')
# ('224', ': batch_gen_loss : 1.03146, dis_loss :1.02116')
# ('224', ': batch_gen_loss : 1.06319, dis_loss :1.26683')
# Model saved in file : ../gan_model/model.ckpt-225
# ('225', ': batch_gen_loss : 0.937474, dis_loss :1.08934')
# ('225', ': batch_gen_loss : 0.89168, dis_loss :1.10325')
# ('225', ': batch_gen_loss : 0.983429, dis_loss :1.27294')
# ('225', ': batch_gen_loss : 0.988784, dis_loss :1.17803')
# ('225', ': batch_gen_loss : 1.1174, dis_loss :1.04181')
# ('225', ': batch_gen_loss : 0.928297, dis_loss :1.20415')
# ('225', ': batch_gen_loss : 0.98274, dis_loss :1.17427')
# ('225', ': batch_gen_loss : 0.943441, dis_loss :1.17289')
# ('225', ': batch_gen_loss : 1.00663, dis_loss :1.03401')
# ('225', ': batch_gen_loss : 1.02124, dis_loss :1.10255')
# ('226', ': batch_gen_loss : 0.901422, dis_loss :1.21116')
# ('226', ': batch_gen_loss : 0.851714, dis_loss :1.29011')
# ('226', ': batch_gen_loss : 1.0294, dis_loss :1.06855')
# ('226', ': batch_gen_loss : 0.976359, dis_loss :1.13569')
# ('226', ': batch_gen_loss : 0.979099, dis_loss :1.10723')
# ('226', ': batch_gen_loss : 1.00081, dis_loss :1.13521')
# ('226', ': batch_gen_loss : 1.04178, dis_loss :1.0901')
# ('226', ': batch_gen_loss : 0.936684, dis_loss :1.11159')
# ('226', ': batch_gen_loss : 0.865795, dis_loss :1.38192')
# ('226', ': batch_gen_loss : 0.899489, dis_loss :1.12582')
# ('227', ': batch_gen_loss : 0.930011, dis_loss :1.34916')
# ('227', ': batch_gen_loss : 0.913702, dis_loss :1.24715')
# ('227', ': batch_gen_loss : 0.933533, dis_loss :1.16008')
# ('227', ': batch_gen_loss : 0.951586, dis_loss :1.19266')
# ('227', ': batch_gen_loss : 0.824819, dis_loss :1.30364')
# ('227', ': batch_gen_loss : 0.846181, dis_loss :1.29869')
# ('227', ': batch_gen_loss : 0.886724, dis_loss :1.49494')
# ('227', ': batch_gen_loss : 0.932671, dis_loss :1.10809')
# ('227', ': batch_gen_loss : 0.950016, dis_loss :1.17176')
# ('227', ': batch_gen_loss : 0.898626, dis_loss :1.13042')
# ('228', ': batch_gen_loss : 0.949325, dis_loss :1.09369')
# ('228', ': batch_gen_loss : 1.03456, dis_loss :1.0903')
# ('228', ': batch_gen_loss : 0.971567, dis_loss :1.12333')
# ('228', ': batch_gen_loss : 1.15153, dis_loss :1.22483')
# ('228', ': batch_gen_loss : 0.927582, dis_loss :1.09079')
# ('228', ': batch_gen_loss : 1.00738, dis_loss :1.1869')
# ('228', ': batch_gen_loss : 0.956715, dis_loss :1.07607')
# ('228', ': batch_gen_loss : 1.07531, dis_loss :0.910188')
# ('228', ': batch_gen_loss : 0.96659, dis_loss :1.1768')
# ('228', ': batch_gen_loss : 0.853953, dis_loss :1.18564')
# ('229', ': batch_gen_loss : 0.871317, dis_loss :1.23407')
# ('229', ': batch_gen_loss : 0.904209, dis_loss :1.22242')
# ('229', ': batch_gen_loss : 0.945945, dis_loss :1.23147')
# ('229', ': batch_gen_loss : 1.05651, dis_loss :1.19362')
# ('229', ': batch_gen_loss : 0.831598, dis_loss :1.12919')
# ('229', ': batch_gen_loss : 0.95899, dis_loss :1.16031')
# ('229', ': batch_gen_loss : 0.964847, dis_loss :1.19958')
# ('229', ': batch_gen_loss : 1.01568, dis_loss :1.07626')
# ('229', ': batch_gen_loss : 1.02116, dis_loss :1.06895')
# ('229', ': batch_gen_loss : 1.10509, dis_loss :0.949361')
# Model saved in file : ../gan_model/model.ckpt-230
# ('230', ': batch_gen_loss : 0.907499, dis_loss :1.15201')
# ('230', ': batch_gen_loss : 0.925826, dis_loss :1.2745')
# ('230', ': batch_gen_loss : 1.09744, dis_loss :0.996347')
# ('230', ': batch_gen_loss : 1.02199, dis_loss :1.13329')
# ('230', ': batch_gen_loss : 0.959032, dis_loss :0.987774')
# ('230', ': batch_gen_loss : 0.900584, dis_loss :1.27643')
# ('230', ': batch_gen_loss : 0.951299, dis_loss :1.19814')
# ('230', ': batch_gen_loss : 0.888588, dis_loss :1.0511')
# ('230', ': batch_gen_loss : 1.03003, dis_loss :1.12538')
# ('230', ': batch_gen_loss : 0.938952, dis_loss :1.2175')
# ('231', ': batch_gen_loss : 0.887509, dis_loss :1.08008')
# ('231', ': batch_gen_loss : 0.875023, dis_loss :1.17833')
# ('231', ': batch_gen_loss : 0.89379, dis_loss :1.1774')
# ('231', ': batch_gen_loss : 0.961305, dis_loss :1.0161')
# ('231', ': batch_gen_loss : 0.897955, dis_loss :1.39553')
# ('231', ': batch_gen_loss : 1.04778, dis_loss :1.23989')
# ('231', ': batch_gen_loss : 0.855024, dis_loss :1.23431')
# ('231', ': batch_gen_loss : 0.900031, dis_loss :1.08344')
# ('231', ': batch_gen_loss : 1.01703, dis_loss :1.11295')
# ('231', ': batch_gen_loss : 1.06452, dis_loss :0.984454')
# ('232', ': batch_gen_loss : 0.946583, dis_loss :1.09753')
# ('232', ': batch_gen_loss : 0.861373, dis_loss :1.19932')
# ('232', ': batch_gen_loss : 1.15796, dis_loss :1.03465')
# ('232', ': batch_gen_loss : 1.06143, dis_loss :1.16631')
# ('232', ': batch_gen_loss : 0.976823, dis_loss :1.06712')
# ('232', ': batch_gen_loss : 1.02478, dis_loss :0.996385')
# ('232', ': batch_gen_loss : 1.04569, dis_loss :1.20245')
# ('232', ': batch_gen_loss : 0.969518, dis_loss :1.09112')
# ('232', ': batch_gen_loss : 0.94641, dis_loss :0.891434')
# ('232', ': batch_gen_loss : 1.07025, dis_loss :0.990166')
# ('233', ': batch_gen_loss : 1.06955, dis_loss :1.1561')
# ('233', ': batch_gen_loss : 1.04269, dis_loss :1.04604')
# ('233', ': batch_gen_loss : 1.11775, dis_loss :1.09896')
# ('233', ': batch_gen_loss : 1.22472, dis_loss :0.915557')
# ('233', ': batch_gen_loss : 1.10097, dis_loss :1.0344')
# ('233', ': batch_gen_loss : 0.882399, dis_loss :1.14971')
# ('233', ': batch_gen_loss : 1.01549, dis_loss :0.992771')
# ('233', ': batch_gen_loss : 1.12618, dis_loss :1.0395')
# ('233', ': batch_gen_loss : 0.874635, dis_loss :1.17658')
# ('233', ': batch_gen_loss : 1.03502, dis_loss :1.309')
# ('234', ': batch_gen_loss : 0.957043, dis_loss :1.11387')
# ('234', ': batch_gen_loss : 1.01077, dis_loss :1.15649')
# ('234', ': batch_gen_loss : 0.958756, dis_loss :1.19553')
# ('234', ': batch_gen_loss : 0.900367, dis_loss :1.25922')
# ('234', ': batch_gen_loss : 0.917018, dis_loss :1.19779')
# ('234', ': batch_gen_loss : 0.813219, dis_loss :1.32552')
# ('234', ': batch_gen_loss : 0.914079, dis_loss :1.12946')
# ('234', ': batch_gen_loss : 0.814707, dis_loss :1.29679')
# ('234', ': batch_gen_loss : 0.885875, dis_loss :1.18562')
# ('234', ': batch_gen_loss : 0.938909, dis_loss :1.195')
# Model saved in file : ../gan_model/model.ckpt-235
# ('235', ': batch_gen_loss : 0.900861, dis_loss :1.22338')
# ('235', ': batch_gen_loss : 0.891403, dis_loss :1.09227')
# ('235', ': batch_gen_loss : 0.91928, dis_loss :1.24779')
# ('235', ': batch_gen_loss : 0.970706, dis_loss :1.28955')
# ('235', ': batch_gen_loss : 0.86323, dis_loss :1.27159')
# ('235', ': batch_gen_loss : 0.791454, dis_loss :1.25812')
# ('235', ': batch_gen_loss : 1.01525, dis_loss :1.24794')
# ('235', ': batch_gen_loss : 1.03653, dis_loss :1.10895')
# ('235', ': batch_gen_loss : 0.791738, dis_loss :1.17676')
# ('235', ': batch_gen_loss : 0.881033, dis_loss :1.24983')
# ('236', ': batch_gen_loss : 0.88616, dis_loss :1.27896')
# ('236', ': batch_gen_loss : 1.07865, dis_loss :1.08251')
# ('236', ': batch_gen_loss : 0.840603, dis_loss :1.30275')
# ('236', ': batch_gen_loss : 0.917073, dis_loss :1.16581')
# ('236', ': batch_gen_loss : 0.928562, dis_loss :1.26454')
# ('236', ': batch_gen_loss : 0.857074, dis_loss :1.23872')
# ('236', ': batch_gen_loss : 0.983494, dis_loss :1.09962')
# ('236', ': batch_gen_loss : 0.935486, dis_loss :1.33139')
# ('236', ': batch_gen_loss : 0.839647, dis_loss :1.20347')
# ('236', ': batch_gen_loss : 0.910892, dis_loss :1.13107')
# ('237', ': batch_gen_loss : 0.890791, dis_loss :1.20512')
# ('237', ': batch_gen_loss : 0.892394, dis_loss :1.13654')
# ('237', ': batch_gen_loss : 0.929391, dis_loss :1.15203')
# ('237', ': batch_gen_loss : 1.01043, dis_loss :1.18747')
# ('237', ': batch_gen_loss : 0.982343, dis_loss :1.12923')
# ('237', ': batch_gen_loss : 0.973442, dis_loss :1.02777')
# ('237', ': batch_gen_loss : 0.928318, dis_loss :1.21683')
# ('237', ': batch_gen_loss : 0.858316, dis_loss :1.19367')
# ('237', ': batch_gen_loss : 1.06394, dis_loss :1.08619')
# ('237', ': batch_gen_loss : 0.95398, dis_loss :1.15955')
# ('238', ': batch_gen_loss : 1.14978, dis_loss :0.982945')
# ('238', ': batch_gen_loss : 1.10954, dis_loss :1.06636')
# ('238', ': batch_gen_loss : 1.10655, dis_loss :1.03247')
# ('238', ': batch_gen_loss : 0.994873, dis_loss :1.01267')
# ('238', ': batch_gen_loss : 0.879261, dis_loss :1.16619')
# ('238', ': batch_gen_loss : 0.738849, dis_loss :1.13158')
# ('238', ': batch_gen_loss : 1.16599, dis_loss :1.04374')
# ('238', ': batch_gen_loss : 1.06324, dis_loss :1.1641')
# ('238', ': batch_gen_loss : 1.12867, dis_loss :1.06536')
# ('238', ': batch_gen_loss : 1.13975, dis_loss :0.958279')
# ('239', ': batch_gen_loss : 1.144, dis_loss :0.919466')
# ('239', ': batch_gen_loss : 0.931913, dis_loss :1.31456')
# ('239', ': batch_gen_loss : 0.889307, dis_loss :1.27252')
# ('239', ': batch_gen_loss : 0.964184, dis_loss :1.25675')
# ('239', ': batch_gen_loss : 1.03403, dis_loss :1.25809')
# ('239', ': batch_gen_loss : 0.992211, dis_loss :1.09549')
# ('239', ': batch_gen_loss : 1.11287, dis_loss :0.932582')
# ('239', ': batch_gen_loss : 0.969073, dis_loss :1.11425')
# ('239', ': batch_gen_loss : 0.942517, dis_loss :1.12668')
# ('239', ': batch_gen_loss : 1.00506, dis_loss :1.11738')
# Model saved in file : ../gan_model/model.ckpt-240
# ('240', ': batch_gen_loss : 1.02159, dis_loss :0.90559')
# ('240', ': batch_gen_loss : 0.951499, dis_loss :1.042')
# ('240', ': batch_gen_loss : 0.979334, dis_loss :1.21842')
# ('240', ': batch_gen_loss : 0.965947, dis_loss :1.03577')
# ('240', ': batch_gen_loss : 1.11182, dis_loss :0.857278')
# ('240', ': batch_gen_loss : 0.984279, dis_loss :1.10164')
# ('240', ': batch_gen_loss : 0.972429, dis_loss :1.18259')
# ('240', ': batch_gen_loss : 1.04833, dis_loss :1.09444')
# ('240', ': batch_gen_loss : 1.00598, dis_loss :1.28529')
# ('240', ': batch_gen_loss : 1.00879, dis_loss :1.03667')
# ('241', ': batch_gen_loss : 0.90272, dis_loss :1.31073')
# ('241', ': batch_gen_loss : 1.04791, dis_loss :1.08151')
# ('241', ': batch_gen_loss : 0.874142, dis_loss :1.40174')
# ('241', ': batch_gen_loss : 0.925576, dis_loss :1.07663')
# ('241', ': batch_gen_loss : 0.938668, dis_loss :1.2099')
# ('241', ': batch_gen_loss : 1.03595, dis_loss :1.09926')
# ('241', ': batch_gen_loss : 0.976114, dis_loss :1.23213')
# ('241', ': batch_gen_loss : 0.93445, dis_loss :1.11402')
# ('241', ': batch_gen_loss : 1.26609, dis_loss :1.2191')
# ('241', ': batch_gen_loss : 0.957446, dis_loss :1.25983')
# ('242', ': batch_gen_loss : 0.956535, dis_loss :1.11964')
# ('242', ': batch_gen_loss : 0.8717, dis_loss :1.31939')
# ('242', ': batch_gen_loss : 0.837954, dis_loss :1.35701')
# ('242', ': batch_gen_loss : 0.859807, dis_loss :1.187')
# ('242', ': batch_gen_loss : 1.01903, dis_loss :1.41564')
# ('242', ': batch_gen_loss : 0.978854, dis_loss :1.12883')
# ('242', ': batch_gen_loss : 0.89659, dis_loss :1.20284')
# ('242', ': batch_gen_loss : 0.935364, dis_loss :0.941088')
# ('242', ': batch_gen_loss : 0.864171, dis_loss :1.11733')
# ('242', ': batch_gen_loss : 0.963178, dis_loss :1.1743')
# ('243', ': batch_gen_loss : 0.992607, dis_loss :1.07911')
# ('243', ': batch_gen_loss : 0.878369, dis_loss :1.02592')
# ('243', ': batch_gen_loss : 0.891344, dis_loss :1.15213')
# ('243', ': batch_gen_loss : 0.961266, dis_loss :1.22177')
# ('243', ': batch_gen_loss : 1.00919, dis_loss :1.1235')
# ('243', ': batch_gen_loss : 0.879838, dis_loss :1.20258')
# ('243', ': batch_gen_loss : 0.732626, dis_loss :1.36316')
# ('243', ': batch_gen_loss : 0.84465, dis_loss :1.26999')
# ('243', ': batch_gen_loss : 0.979513, dis_loss :1.12085')
# ('243', ': batch_gen_loss : 0.949538, dis_loss :1.31564')
# ('244', ': batch_gen_loss : 0.933669, dis_loss :1.09589')
# ('244', ': batch_gen_loss : 0.993752, dis_loss :1.10295')
# ('244', ': batch_gen_loss : 1.10553, dis_loss :1.19356')
# ('244', ': batch_gen_loss : 0.901457, dis_loss :1.24059')
# ('244', ': batch_gen_loss : 0.999916, dis_loss :1.15303')
# ('244', ': batch_gen_loss : 0.897436, dis_loss :1.15004')
# ('244', ': batch_gen_loss : 0.918406, dis_loss :1.23639')
# ('244', ': batch_gen_loss : 1.03216, dis_loss :1.09032')
# ('244', ': batch_gen_loss : 0.929797, dis_loss :1.28485')
# ('244', ': batch_gen_loss : 1.06437, dis_loss :1.14052')
# Model saved in file : ../gan_model/model.ckpt-245
# ('245', ': batch_gen_loss : 0.894575, dis_loss :1.14511')
# ('245', ': batch_gen_loss : 0.908937, dis_loss :1.13514')
# ('245', ': batch_gen_loss : 0.940486, dis_loss :1.20256')
# ('245', ': batch_gen_loss : 0.933069, dis_loss :1.16234')
# ('245', ': batch_gen_loss : 0.818686, dis_loss :1.28387')
# ('245', ': batch_gen_loss : 0.74084, dis_loss :1.2537')
# ('245', ': batch_gen_loss : 0.804842, dis_loss :1.28732')
# ('245', ': batch_gen_loss : 0.915788, dis_loss :1.13833')
# ('245', ': batch_gen_loss : 0.983251, dis_loss :1.12586')
# ('245', ': batch_gen_loss : 0.895512, dis_loss :1.05207')
# ('246', ': batch_gen_loss : 0.940948, dis_loss :1.14833')
# ('246', ': batch_gen_loss : 0.768433, dis_loss :1.29914')
# ('246', ': batch_gen_loss : 0.818593, dis_loss :1.18016')
# ('246', ': batch_gen_loss : 0.850518, dis_loss :1.24113')
# ('246', ': batch_gen_loss : 1.06214, dis_loss :1.1869')
# ('246', ': batch_gen_loss : 0.926894, dis_loss :1.0722')
# ('246', ': batch_gen_loss : 0.835363, dis_loss :1.21944')
# ('246', ': batch_gen_loss : 0.826151, dis_loss :1.23556')
# ('246', ': batch_gen_loss : 1.1194, dis_loss :1.26334')
# ('246', ': batch_gen_loss : 0.982877, dis_loss :1.17008')
# ('247', ': batch_gen_loss : 0.89055, dis_loss :1.18894')
# ('247', ': batch_gen_loss : 0.851212, dis_loss :1.38725')
# ('247', ': batch_gen_loss : 1.00273, dis_loss :1.20189')
# ('247', ': batch_gen_loss : 0.935579, dis_loss :1.28587')
# ('247', ': batch_gen_loss : 0.914902, dis_loss :1.27201')
# ('247', ': batch_gen_loss : 0.756932, dis_loss :1.34222')
# ('247', ': batch_gen_loss : 0.985807, dis_loss :1.141')
# ('247', ': batch_gen_loss : 0.736582, dis_loss :1.3311')
# ('247', ': batch_gen_loss : 0.890663, dis_loss :1.11848')
# ('247', ': batch_gen_loss : 0.918536, dis_loss :1.27623')
# ('248', ': batch_gen_loss : 0.786114, dis_loss :1.34605')
# ('248', ': batch_gen_loss : 1.04163, dis_loss :1.07599')
# ('248', ': batch_gen_loss : 0.854677, dis_loss :1.24925')
# ('248', ': batch_gen_loss : 0.879087, dis_loss :1.15223')
# ('248', ': batch_gen_loss : 0.87783, dis_loss :1.25821')
# ('248', ': batch_gen_loss : 0.940989, dis_loss :1.35232')
# ('248', ': batch_gen_loss : 0.866729, dis_loss :1.23716')
# ('248', ': batch_gen_loss : 0.876016, dis_loss :1.10254')
# ('248', ': batch_gen_loss : 0.715054, dis_loss :1.3132')
# ('248', ': batch_gen_loss : 0.998927, dis_loss :1.28712')
# ('249', ': batch_gen_loss : 0.719879, dis_loss :1.26892')
# ('249', ': batch_gen_loss : 1.01361, dis_loss :1.14315')
# ('249', ': batch_gen_loss : 0.990091, dis_loss :1.06111')
# ('249', ': batch_gen_loss : 0.991676, dis_loss :1.43552')
# ('249', ': batch_gen_loss : 0.899757, dis_loss :1.25835')
# ('249', ': batch_gen_loss : 0.766935, dis_loss :1.3566')
# ('249', ': batch_gen_loss : 0.939643, dis_loss :1.33285')
# ('249', ': batch_gen_loss : 0.963325, dis_loss :1.18913')
# ('249', ': batch_gen_loss : 0.897305, dis_loss :1.24349')
# ('249', ': batch_gen_loss : 0.779492, dis_loss :1.3354')
# Model saved in file : ../gan_model/model.ckpt-250
# ('250', ': batch_gen_loss : 0.76212, dis_loss :1.46997')
# ('250', ': batch_gen_loss : 0.881268, dis_loss :1.25362')
# ('250', ': batch_gen_loss : 0.778289, dis_loss :1.24171')
# ('250', ': batch_gen_loss : 0.866155, dis_loss :1.33086')
# ('250', ': batch_gen_loss : 0.891659, dis_loss :1.24392')
# ('250', ': batch_gen_loss : 0.828584, dis_loss :1.3691')
# ('250', ': batch_gen_loss : 1.00729, dis_loss :1.20272')
# ('250', ': batch_gen_loss : 0.874014, dis_loss :1.19485')
# ('250', ': batch_gen_loss : 0.996607, dis_loss :1.25956')
# ('250', ': batch_gen_loss : 0.966501, dis_loss :1.13547')
# ('251', ': batch_gen_loss : 0.887709, dis_loss :1.37392')
# ('251', ': batch_gen_loss : 0.847513, dis_loss :1.16854')
# ('251', ': batch_gen_loss : 0.809145, dis_loss :1.20186')
# ('251', ': batch_gen_loss : 1.05084, dis_loss :1.08067')
# ('251', ': batch_gen_loss : 0.88463, dis_loss :1.18077')
# ('251', ': batch_gen_loss : 0.877457, dis_loss :1.24111')
# ('251', ': batch_gen_loss : 0.870115, dis_loss :1.31604')
# ('251', ': batch_gen_loss : 1.01384, dis_loss :1.22607')
# ('251', ': batch_gen_loss : 0.887022, dis_loss :1.20453')
# ('251', ': batch_gen_loss : 0.829246, dis_loss :1.29442')
# ('252', ': batch_gen_loss : 1.03588, dis_loss :1.22866')
# ('252', ': batch_gen_loss : 0.813783, dis_loss :1.24494')
# ('252', ': batch_gen_loss : 0.860432, dis_loss :1.27806')
# ('252', ': batch_gen_loss : 0.814728, dis_loss :1.35338')
# ('252', ': batch_gen_loss : 0.961225, dis_loss :1.05675')
# ('252', ': batch_gen_loss : 0.902424, dis_loss :1.2321')
# ('252', ': batch_gen_loss : 0.9165, dis_loss :1.21654')
# ('252', ': batch_gen_loss : 0.758948, dis_loss :1.217')
# ('252', ': batch_gen_loss : 0.871359, dis_loss :1.3941')
# ('252', ': batch_gen_loss : 0.819136, dis_loss :1.35068')
# ('253', ': batch_gen_loss : 0.764454, dis_loss :1.26679')
# ('253', ': batch_gen_loss : 1.01004, dis_loss :1.03814')
# ('253', ': batch_gen_loss : 0.872231, dis_loss :1.24244')
# ('253', ': batch_gen_loss : 0.81462, dis_loss :1.25251')
# ('253', ': batch_gen_loss : 0.851733, dis_loss :1.24698')
# ('253', ': batch_gen_loss : 0.978995, dis_loss :1.1686')
# ('253', ': batch_gen_loss : 0.928186, dis_loss :1.20996')
# ('253', ': batch_gen_loss : 0.996327, dis_loss :1.32558')
# ('253', ': batch_gen_loss : 1.05693, dis_loss :1.10135')
# ('253', ': batch_gen_loss : 0.895551, dis_loss :1.18819')
# ('254', ': batch_gen_loss : 0.869518, dis_loss :1.26224')
# ('254', ': batch_gen_loss : 0.875683, dis_loss :1.10433')
# ('254', ': batch_gen_loss : 0.790886, dis_loss :1.37693')
# ('254', ': batch_gen_loss : 0.969885, dis_loss :1.14025')
# ('254', ': batch_gen_loss : 0.862039, dis_loss :1.41099')
# ('254', ': batch_gen_loss : 1.03726, dis_loss :1.08488')
# ('254', ': batch_gen_loss : 0.899315, dis_loss :1.28361')
# ('254', ': batch_gen_loss : 1.06287, dis_loss :1.17629')
# ('254', ': batch_gen_loss : 0.920341, dis_loss :1.0742')
# ('254', ': batch_gen_loss : 0.859361, dis_loss :1.23711')
# Model saved in file : ../gan_model/model.ckpt-255
# ('255', ': batch_gen_loss : 0.833124, dis_loss :1.18885')
# ('255', ': batch_gen_loss : 0.89809, dis_loss :1.25584')
# ('255', ': batch_gen_loss : 1.06364, dis_loss :1.10924')
# ('255', ': batch_gen_loss : 0.974153, dis_loss :1.1468')
# ('255', ': batch_gen_loss : 0.83836, dis_loss :1.35655')
# ('255', ': batch_gen_loss : 0.968498, dis_loss :1.15535')
# ('255', ': batch_gen_loss : 0.918633, dis_loss :1.17662')
# ('255', ': batch_gen_loss : 1.10395, dis_loss :1.05901')
# ('255', ': batch_gen_loss : 0.844346, dis_loss :1.20145')
# ('255', ': batch_gen_loss : 0.782343, dis_loss :1.19409')
# ('256', ': batch_gen_loss : 0.785936, dis_loss :1.1315')
# ('256', ': batch_gen_loss : 0.859112, dis_loss :1.22007')
# ('256', ': batch_gen_loss : 0.902772, dis_loss :1.21242')
# ('256', ': batch_gen_loss : 0.91716, dis_loss :1.13767')
# ('256', ': batch_gen_loss : 0.773566, dis_loss :1.30239')
# ('256', ': batch_gen_loss : 0.811296, dis_loss :1.24132')
# ('256', ': batch_gen_loss : 0.832619, dis_loss :1.19414')
# ('256', ': batch_gen_loss : 1.09008, dis_loss :1.14346')
# ('256', ': batch_gen_loss : 1.08003, dis_loss :1.19812')
# ('256', ': batch_gen_loss : 1.01907, dis_loss :1.11458')
# ('257', ': batch_gen_loss : 0.835272, dis_loss :1.20997')
# ('257', ': batch_gen_loss : 0.794802, dis_loss :1.20686')
# ('257', ': batch_gen_loss : 0.820956, dis_loss :1.30727')
# ('257', ': batch_gen_loss : 0.846889, dis_loss :1.32297')
# ('257', ': batch_gen_loss : 0.726698, dis_loss :1.29499')
# ('257', ': batch_gen_loss : 0.792276, dis_loss :1.2609')
# ('257', ': batch_gen_loss : 0.913391, dis_loss :1.20003')
# ('257', ': batch_gen_loss : 0.894034, dis_loss :1.13354')
# ('257', ': batch_gen_loss : 0.966439, dis_loss :1.13745')
# ('257', ': batch_gen_loss : 0.886166, dis_loss :1.25768')
# ('258', ': batch_gen_loss : 1.03785, dis_loss :1.1839')
# ('258', ': batch_gen_loss : 0.980436, dis_loss :1.08034')
# ('258', ': batch_gen_loss : 1.07645, dis_loss :1.21509')
# ('258', ': batch_gen_loss : 0.847391, dis_loss :1.05061')
# ('258', ': batch_gen_loss : 0.909539, dis_loss :1.15548')
# ('258', ': batch_gen_loss : 1.04691, dis_loss :1.15067')
# ('258', ': batch_gen_loss : 1.09245, dis_loss :1.12146')
# ('258', ': batch_gen_loss : 1.0706, dis_loss :0.977651')
# ('258', ': batch_gen_loss : 0.868327, dis_loss :1.24832')
# ('258', ': batch_gen_loss : 1.21542, dis_loss :1.21852')
# ('259', ': batch_gen_loss : 0.92148, dis_loss :1.10486')
# ('259', ': batch_gen_loss : 0.888612, dis_loss :1.27307')
# ('259', ': batch_gen_loss : 0.840547, dis_loss :1.22936')
# ('259', ': batch_gen_loss : 0.986008, dis_loss :1.08584')
# ('259', ': batch_gen_loss : 1.17869, dis_loss :1.12143')
# ('259', ': batch_gen_loss : 0.98359, dis_loss :1.06802')
# ('259', ': batch_gen_loss : 1.11166, dis_loss :1.02102')
# ('259', ': batch_gen_loss : 0.730786, dis_loss :1.27544')
# ('259', ': batch_gen_loss : 0.838902, dis_loss :1.30982')
# ('259', ': batch_gen_loss : 1.07774, dis_loss :1.06979')
# Model saved in file : ../gan_model/model.ckpt-260
# ('260', ': batch_gen_loss : 1.12176, dis_loss :1.02457')
# ('260', ': batch_gen_loss : 1.11398, dis_loss :1.11136')
# ('260', ': batch_gen_loss : 0.983072, dis_loss :1.17414')
# ('260', ': batch_gen_loss : 1.00893, dis_loss :1.07514')
# ('260', ': batch_gen_loss : 1.00999, dis_loss :1.20201')
# ('260', ': batch_gen_loss : 0.947756, dis_loss :1.13818')
# ('260', ': batch_gen_loss : 1.04399, dis_loss :1.08209')
# ('260', ': batch_gen_loss : 1.03061, dis_loss :1.05526')
# ('260', ': batch_gen_loss : 0.916881, dis_loss :1.1321')
# ('260', ': batch_gen_loss : 0.972792, dis_loss :1.11619')
# ('261', ': batch_gen_loss : 0.906383, dis_loss :1.1772')
# ('261', ': batch_gen_loss : 0.857128, dis_loss :1.24233')
# ('261', ': batch_gen_loss : 0.828689, dis_loss :1.25267')
# ('261', ': batch_gen_loss : 0.92827, dis_loss :1.10603')
# ('261', ': batch_gen_loss : 0.973695, dis_loss :1.16154')
# ('261', ': batch_gen_loss : 0.954216, dis_loss :1.09779')
# ('261', ': batch_gen_loss : 1.04801, dis_loss :1.02536')
# ('261', ': batch_gen_loss : 0.998893, dis_loss :1.01942')
# ('261', ': batch_gen_loss : 1.00193, dis_loss :1.08498')
# ('261', ': batch_gen_loss : 1.01372, dis_loss :1.26058')
# ('262', ': batch_gen_loss : 1.01058, dis_loss :1.12488')
# ('262', ': batch_gen_loss : 1.07589, dis_loss :1.17734')
# ('262', ': batch_gen_loss : 0.845753, dis_loss :1.22906')
# ('262', ': batch_gen_loss : 0.915599, dis_loss :1.27053')
# ('262', ': batch_gen_loss : 0.884157, dis_loss :1.26959')
# ('262', ': batch_gen_loss : 0.792252, dis_loss :1.31319')
# ('262', ': batch_gen_loss : 0.913887, dis_loss :1.1478')
# ('262', ': batch_gen_loss : 1.13522, dis_loss :1.16009')
# ('262', ': batch_gen_loss : 1.00491, dis_loss :1.12733')
# ('262', ': batch_gen_loss : 1.08341, dis_loss :0.994987')
# ('263', ': batch_gen_loss : 1.02291, dis_loss :1.04984')
# ('263', ': batch_gen_loss : 0.857538, dis_loss :1.11518')
# ('263', ': batch_gen_loss : 1.319, dis_loss :1.01117')
# ('263', ': batch_gen_loss : 0.967756, dis_loss :1.11977')
# ('263', ': batch_gen_loss : 0.837202, dis_loss :1.17422')
# ('263', ': batch_gen_loss : 0.881773, dis_loss :1.20751')
# ('263', ': batch_gen_loss : 1.11632, dis_loss :1.04515')
# ('263', ': batch_gen_loss : 1.14206, dis_loss :1.12542')
# ('263', ': batch_gen_loss : 0.889213, dis_loss :1.07745')
# ('263', ': batch_gen_loss : 0.992229, dis_loss :1.07045')
# ('264', ': batch_gen_loss : 0.943237, dis_loss :1.18588')
# ('264', ': batch_gen_loss : 0.877456, dis_loss :1.0676')
# ('264', ': batch_gen_loss : 0.885261, dis_loss :1.27803')
# ('264', ': batch_gen_loss : 0.94373, dis_loss :1.051')
# ('264', ': batch_gen_loss : 1.03932, dis_loss :1.0634')
# ('264', ': batch_gen_loss : 1.04025, dis_loss :1.0857')
# ('264', ': batch_gen_loss : 0.984331, dis_loss :1.13007')
# ('264', ': batch_gen_loss : 1.05818, dis_loss :1.06563')
# ('264', ': batch_gen_loss : 0.896695, dis_loss :1.22936')
# ('264', ': batch_gen_loss : 0.843658, dis_loss :1.28079')
# Model saved in file : ../gan_model/model.ckpt-265
# ('265', ': batch_gen_loss : 1.08909, dis_loss :1.23241')
# ('265', ': batch_gen_loss : 0.865538, dis_loss :1.31151')
# ('265', ': batch_gen_loss : 0.69247, dis_loss :1.39299')
# ('265', ': batch_gen_loss : 1.04281, dis_loss :1.29109')
# ('265', ': batch_gen_loss : 0.848144, dis_loss :1.24562')
# ('265', ': batch_gen_loss : 1.1052, dis_loss :1.12553')
# ('265', ': batch_gen_loss : 0.893265, dis_loss :1.46816')
# ('265', ': batch_gen_loss : 0.866076, dis_loss :1.26665')
# ('265', ': batch_gen_loss : 0.856082, dis_loss :1.1543')
# ('265', ': batch_gen_loss : 0.872472, dis_loss :1.34334')
# ('266', ': batch_gen_loss : 0.933864, dis_loss :1.39646')
# ('266', ': batch_gen_loss : 0.911264, dis_loss :1.40218')
# ('266', ': batch_gen_loss : 0.835283, dis_loss :1.31544')
# ('266', ': batch_gen_loss : 1.00231, dis_loss :1.14018')
# ('266', ': batch_gen_loss : 0.803844, dis_loss :1.45518')
# ('266', ': batch_gen_loss : 0.89058, dis_loss :1.23494')
# ('266', ': batch_gen_loss : 0.801701, dis_loss :1.29931')
# ('266', ': batch_gen_loss : 0.874943, dis_loss :1.17962')
# ('266', ': batch_gen_loss : 0.778083, dis_loss :1.26016')
# ('266', ': batch_gen_loss : 0.89925, dis_loss :1.2857')
# ('267', ': batch_gen_loss : 0.873448, dis_loss :1.12294')
# ('267', ': batch_gen_loss : 0.790239, dis_loss :1.34129')
# ('267', ': batch_gen_loss : 0.809515, dis_loss :1.2953')
# ('267', ': batch_gen_loss : 0.973091, dis_loss :1.24273')
# ('267', ': batch_gen_loss : 0.949996, dis_loss :1.20346')
# ('267', ': batch_gen_loss : 0.933381, dis_loss :1.27331')
# ('267', ': batch_gen_loss : 0.875572, dis_loss :1.13911')
# ('267', ': batch_gen_loss : 0.902738, dis_loss :1.15027')
# ('267', ': batch_gen_loss : 0.891517, dis_loss :1.11739')
# ('267', ': batch_gen_loss : 0.839379, dis_loss :1.3776')
# ('268', ': batch_gen_loss : 0.852059, dis_loss :1.29149')
# ('268', ': batch_gen_loss : 1.00446, dis_loss :1.10893')
# ('268', ': batch_gen_loss : 1.04166, dis_loss :1.09305')
# ('268', ': batch_gen_loss : 0.962985, dis_loss :1.07253')
# ('268', ': batch_gen_loss : 1.01396, dis_loss :1.04059')
# ('268', ': batch_gen_loss : 1.09769, dis_loss :1.13328')
# ('268', ': batch_gen_loss : 1.01115, dis_loss :1.06885')
# ('268', ': batch_gen_loss : 0.825802, dis_loss :1.19208')
# ('268', ': batch_gen_loss : 0.837953, dis_loss :1.29141')
# ('268', ': batch_gen_loss : 0.980228, dis_loss :1.16626')
# ('269', ': batch_gen_loss : 0.962185, dis_loss :1.31261')
# ('269', ': batch_gen_loss : 0.929315, dis_loss :1.08989')
# ('269', ': batch_gen_loss : 0.938522, dis_loss :1.17562')
# ('269', ': batch_gen_loss : 0.982989, dis_loss :1.12324')
# ('269', ': batch_gen_loss : 0.817477, dis_loss :1.14956')
# ('269', ': batch_gen_loss : 0.782087, dis_loss :1.18809')
# ('269', ': batch_gen_loss : 0.95616, dis_loss :1.05616')
# ('269', ': batch_gen_loss : 0.944595, dis_loss :1.13759')
# ('269', ': batch_gen_loss : 1.03112, dis_loss :1.1947')
# ('269', ': batch_gen_loss : 0.884951, dis_loss :1.19586')
# Model saved in file : ../gan_model/model.ckpt-270
# ('270', ': batch_gen_loss : 1.00024, dis_loss :1.28058')
# ('270', ': batch_gen_loss : 1.03869, dis_loss :1.15925')
# ('270', ': batch_gen_loss : 1.06629, dis_loss :1.1144')
# ('270', ': batch_gen_loss : 1.06806, dis_loss :1.15269')
# ('270', ': batch_gen_loss : 1.02445, dis_loss :1.41489')
# ('270', ': batch_gen_loss : 1.06198, dis_loss :1.01507')
# ('270', ': batch_gen_loss : 0.936954, dis_loss :1.12321')
# ('270', ': batch_gen_loss : 0.910066, dis_loss :1.22133')
# ('270', ': batch_gen_loss : 1.04309, dis_loss :1.14269')
# ('270', ': batch_gen_loss : 1.02968, dis_loss :1.20911')
# ('271', ': batch_gen_loss : 0.863186, dis_loss :1.19217')
# ('271', ': batch_gen_loss : 1.07613, dis_loss :1.15853')
# ('271', ': batch_gen_loss : 0.986491, dis_loss :1.14563')
# ('271', ': batch_gen_loss : 1.17143, dis_loss :1.19492')
# ('271', ': batch_gen_loss : 0.964816, dis_loss :1.23345')
# ('271', ': batch_gen_loss : 0.870055, dis_loss :1.04836')
# ('271', ': batch_gen_loss : 0.953421, dis_loss :1.15421')
# ('271', ': batch_gen_loss : 0.833203, dis_loss :1.18633')
# ('271', ': batch_gen_loss : 0.954899, dis_loss :1.21816')
# ('271', ': batch_gen_loss : 1.01681, dis_loss :1.21302')
# ('272', ': batch_gen_loss : 0.806887, dis_loss :1.04809')
# ('272', ': batch_gen_loss : 1.05078, dis_loss :1.10896')
# ('272', ': batch_gen_loss : 0.807594, dis_loss :1.28117')
# ('272', ': batch_gen_loss : 1.17333, dis_loss :1.02871')
# ('272', ': batch_gen_loss : 0.957115, dis_loss :1.02284')
# ('272', ': batch_gen_loss : 0.791342, dis_loss :1.25599')
# ('272', ': batch_gen_loss : 1.01947, dis_loss :1.36958')
# ('272', ': batch_gen_loss : 0.941454, dis_loss :1.15482')
# ('272', ': batch_gen_loss : 0.9343, dis_loss :1.0803')
# ('272', ': batch_gen_loss : 1.05761, dis_loss :1.12057')
# ('273', ': batch_gen_loss : 0.903014, dis_loss :1.21884')
# ('273', ': batch_gen_loss : 1.04259, dis_loss :1.05716')
# ('273', ': batch_gen_loss : 1.00583, dis_loss :1.09979')
# ('273', ': batch_gen_loss : 0.851393, dis_loss :1.14754')
# ('273', ': batch_gen_loss : 1.09847, dis_loss :1.03316')
# ('273', ': batch_gen_loss : 0.908611, dis_loss :1.18966')
# ('273', ': batch_gen_loss : 1.10306, dis_loss :1.14094')
# ('273', ': batch_gen_loss : 0.842435, dis_loss :1.25602')
# ('273', ': batch_gen_loss : 1.0069, dis_loss :1.0509')
# ('273', ': batch_gen_loss : 0.81436, dis_loss :1.20778')
# ('274', ': batch_gen_loss : 0.9558, dis_loss :1.16989')
# ('274', ': batch_gen_loss : 0.926738, dis_loss :1.35969')
# ('274', ': batch_gen_loss : 1.01912, dis_loss :0.965636')
# ('274', ': batch_gen_loss : 0.845028, dis_loss :1.15495')
# ('274', ': batch_gen_loss : 0.892991, dis_loss :1.07793')
# ('274', ': batch_gen_loss : 1.02934, dis_loss :1.26792')
# ('274', ': batch_gen_loss : 0.904683, dis_loss :1.01762')
# ('274', ': batch_gen_loss : 1.05607, dis_loss :1.0699')
# ('274', ': batch_gen_loss : 0.842614, dis_loss :1.27344')
# ('274', ': batch_gen_loss : 0.869869, dis_loss :1.31527')
# Model saved in file : ../gan_model/model.ckpt-275
# ('275', ': batch_gen_loss : 1.06649, dis_loss :1.22135')
# ('275', ': batch_gen_loss : 0.964841, dis_loss :1.07579')
# ('275', ': batch_gen_loss : 0.926669, dis_loss :1.25209')
# ('275', ': batch_gen_loss : 0.990704, dis_loss :1.02347')
# ('275', ': batch_gen_loss : 1.08776, dis_loss :0.976752')
# ('275', ': batch_gen_loss : 1.02592, dis_loss :0.988536')
# ('275', ': batch_gen_loss : 1.06659, dis_loss :1.15876')
# ('275', ': batch_gen_loss : 1.10298, dis_loss :1.06325')
# ('275', ': batch_gen_loss : 0.840679, dis_loss :1.34853')
# ('275', ': batch_gen_loss : 1.04127, dis_loss :1.11092')
# ('276', ': batch_gen_loss : 1.03947, dis_loss :1.18769')
# ('276', ': batch_gen_loss : 1.0673, dis_loss :1.1582')
# ('276', ': batch_gen_loss : 0.988362, dis_loss :1.08407')
# ('276', ': batch_gen_loss : 0.987788, dis_loss :1.13785')
# ('276', ': batch_gen_loss : 1.07055, dis_loss :1.00343')
# ('276', ': batch_gen_loss : 0.923859, dis_loss :1.14327')
# ('276', ': batch_gen_loss : 1.00368, dis_loss :0.989791')
# ('276', ': batch_gen_loss : 1.01362, dis_loss :1.11377')
# ('276', ': batch_gen_loss : 1.02535, dis_loss :1.20999')
# ('276', ': batch_gen_loss : 1.02282, dis_loss :1.124')
# ('277', ': batch_gen_loss : 1.06392, dis_loss :1.05001')
# ('277', ': batch_gen_loss : 0.961527, dis_loss :1.11613')
# ('277', ': batch_gen_loss : 0.971862, dis_loss :1.20943')
# ('277', ': batch_gen_loss : 1.08432, dis_loss :1.05131')
# ('277', ': batch_gen_loss : 1.10833, dis_loss :1.10568')
# ('277', ': batch_gen_loss : 0.963463, dis_loss :1.2152')
# ('277', ': batch_gen_loss : 0.968085, dis_loss :1.11475')
# ('277', ': batch_gen_loss : 1.09021, dis_loss :1.03203')
# ('277', ': batch_gen_loss : 1.06666, dis_loss :0.983848')
# ('277', ': batch_gen_loss : 1.05398, dis_loss :1.1722')
# ('278', ': batch_gen_loss : 1.12489, dis_loss :1.05733')
# ('278', ': batch_gen_loss : 1.03956, dis_loss :1.18583')
# ('278', ': batch_gen_loss : 1.12323, dis_loss :0.970853')
# ('278', ': batch_gen_loss : 0.964433, dis_loss :1.05631')
# ('278', ': batch_gen_loss : 0.95113, dis_loss :1.31535')
# ('278', ': batch_gen_loss : 0.891893, dis_loss :1.13224')
# ('278', ': batch_gen_loss : 1.10192, dis_loss :1.14226')
# ('278', ': batch_gen_loss : 1.01773, dis_loss :1.12099')
# ('278', ': batch_gen_loss : 1.03662, dis_loss :1.06863')
# ('278', ': batch_gen_loss : 0.991447, dis_loss :1.2327')
# ('279', ': batch_gen_loss : 0.939614, dis_loss :1.19511')
# ('279', ': batch_gen_loss : 1.27101, dis_loss :1.01417')
# ('279', ': batch_gen_loss : 1.14782, dis_loss :1.01964')
# ('279', ': batch_gen_loss : 0.819913, dis_loss :1.24652')
# ('279', ': batch_gen_loss : 1.00495, dis_loss :1.0499')
# ('279', ': batch_gen_loss : 1.2015, dis_loss :1.13233')
# ('279', ': batch_gen_loss : 1.10301, dis_loss :1.10067')
# ('279', ': batch_gen_loss : 1.03671, dis_loss :1.21895')
# ('279', ': batch_gen_loss : 1.18707, dis_loss :1.04514')
# ('279', ': batch_gen_loss : 1.08751, dis_loss :0.985746')
# Model saved in file : ../gan_model/model.ckpt-280
# ('280', ': batch_gen_loss : 0.99116, dis_loss :1.02405')
# ('280', ': batch_gen_loss : 0.975097, dis_loss :1.22698')
# ('280', ': batch_gen_loss : 1.18347, dis_loss :1.15063')
# ('280', ': batch_gen_loss : 1.02289, dis_loss :0.951361')
# ('280', ': batch_gen_loss : 1.09126, dis_loss :0.962431')
# ('280', ': batch_gen_loss : 1.10938, dis_loss :1.0301')
# ('280', ': batch_gen_loss : 0.994103, dis_loss :1.15691')
# ('280', ': batch_gen_loss : 1.10398, dis_loss :1.27355')
# ('280', ': batch_gen_loss : 0.921444, dis_loss :1.21201')
# ('280', ': batch_gen_loss : 1.07448, dis_loss :0.947965')
# ('281', ': batch_gen_loss : 1.07228, dis_loss :1.25223')
# ('281', ': batch_gen_loss : 0.874132, dis_loss :1.36707')
# ('281', ': batch_gen_loss : 0.881425, dis_loss :1.14129')
# ('281', ': batch_gen_loss : 0.851893, dis_loss :1.31888')
# ('281', ': batch_gen_loss : 1.13501, dis_loss :1.1621')
# ('281', ': batch_gen_loss : 0.829808, dis_loss :1.16823')
# ...
# ('396', ': batch_gen_loss : 0.711038, dis_loss :1.35717')
# ('396', ': batch_gen_loss : 0.793915, dis_loss :1.29589')
# ('396', ': batch_gen_loss : 1.00528, dis_loss :1.03138')
# ('397', ': batch_gen_loss : 0.962064, dis_loss :1.21761')
# ('397', ': batch_gen_loss : 0.799495, dis_loss :1.11711')
# ('397', ': batch_gen_loss : 0.94851, dis_loss :1.09317')
# ('397', ': batch_gen_loss : 0.999748, dis_loss :1.41015')
# ('397', ': batch_gen_loss : 1.04375, dis_loss :1.17287')
# ('397', ': batch_gen_loss : 0.826724, dis_loss :1.22603')
# ('397', ': batch_gen_loss : 0.913259, dis_loss :1.24918')
# ('397', ': batch_gen_loss : 1.14152, dis_loss :1.14433')
# ('397', ': batch_gen_loss : 0.922073, dis_loss :1.1362')
# ('397', ': batch_gen_loss : 0.877843, dis_loss :1.12875')
# ('398', ': batch_gen_loss : 0.962922, dis_loss :1.22398')
# ('398', ': batch_gen_loss : 0.933474, dis_loss :1.10687')
# ('398', ': batch_gen_loss : 1.15229, dis_loss :1.05974')
# ('398', ': batch_gen_loss : 1.18306, dis_loss :1.03867')
# ('398', ': batch_gen_loss : 0.911991, dis_loss :1.2561')
# ('398', ': batch_gen_loss : 1.03039, dis_loss :1.25908')
# ('398', ': batch_gen_loss : 0.824109, dis_loss :1.20448')
# ('398', ': batch_gen_loss : 0.90385, dis_loss :1.22332')
# ('398', ': batch_gen_loss : 0.853097, dis_loss :1.17372')
# ('398', ': batch_gen_loss : 0.836844, dis_loss :1.11483')
# ('399', ': batch_gen_loss : 0.897768, dis_loss :1.09427')
# ('399', ': batch_gen_loss : 1.07512, dis_loss :1.11081')
# ('399', ': batch_gen_loss : 0.849406, dis_loss :1.30812')
# ('399', ': batch_gen_loss : 0.927506, dis_loss :1.20637')
# ('399', ': batch_gen_loss : 1.20567, dis_loss :1.11767')
# ('399', ': batch_gen_loss : 0.856704, dis_loss :1.16232')
# ('399', ': batch_gen_loss : 1.10144, dis_loss :1.07057')
# ('399', ': batch_gen_loss : 0.955574, dis_loss :1.1234')
# ('399', ': batch_gen_loss : 0.834077, dis_loss :1.11551')
# ('399', ': batch_gen_loss : 0.891364, dis_loss :1.25386')
# Model saved in file : ../gan_model/model.ckpt-400
# ('400', ': batch_gen_loss : 1.02489, dis_loss :1.06573')
# ('400', ': batch_gen_loss : 1.1558, dis_loss :1.11625')
# ('400', ': batch_gen_loss : 0.853652, dis_loss :1.21056')
# ('400', ': batch_gen_loss : 0.92988, dis_loss :1.23955')
# ('400', ': batch_gen_loss : 0.904387, dis_loss :1.30774')
# ('400', ': batch_gen_loss : 0.966775, dis_loss :1.00084')
# ('400', ': batch_gen_loss : 1.09012, dis_loss :1.19129')
# ('400', ': batch_gen_loss : 0.954773, dis_loss :1.08346')
# ('400', ': batch_gen_loss : 0.924758, dis_loss :1.0642')
# ('400', ': batch_gen_loss : 0.906834, dis_loss :1.26375')
# ('401', ': batch_gen_loss : 0.859653, dis_loss :1.24618')
# ('401', ': batch_gen_loss : 0.90994, dis_loss :1.1766')
# ('401', ': batch_gen_loss : 0.911667, dis_loss :1.27724')
# ('401', ': batch_gen_loss : 0.913054, dis_loss :1.19702')
# ('401', ': batch_gen_loss : 0.871352, dis_loss :1.11099')
# ('401', ': batch_gen_loss : 1.00916, dis_loss :1.1572')
# ('401', ': batch_gen_loss : 1.03348, dis_loss :1.09894')
# ('401', ': batch_gen_loss : 0.714569, dis_loss :1.32625')
# ('401', ': batch_gen_loss : 0.970574, dis_loss :1.15577')
# ('401', ': batch_gen_loss : 1.02065, dis_loss :1.12142')
# ('402', ': batch_gen_loss : 1.10425, dis_loss :1.24167')
# ('402', ': batch_gen_loss : 0.96322, dis_loss :1.07982')
# ('402', ': batch_gen_loss : 0.781387, dis_loss :1.17335')
# ('402', ': batch_gen_loss : 1.06189, dis_loss :1.16398')
# ('402', ': batch_gen_loss : 0.9116, dis_loss :1.19495')
# ('402', ': batch_gen_loss : 0.990902, dis_loss :1.19843')
# ('402', ': batch_gen_loss : 0.939564, dis_loss :1.32566')
# ('402', ': batch_gen_loss : 1.04021, dis_loss :1.16047')
# ('402', ': batch_gen_loss : 0.934204, dis_loss :1.07929')
# ('402', ': batch_gen_loss : 0.869661, dis_loss :1.28125')
# ('403', ': batch_gen_loss : 0.98753, dis_loss :1.15521')
# ('403', ': batch_gen_loss : 1.04969, dis_loss :1.17651')
# ('403', ': batch_gen_loss : 1.03555, dis_loss :1.20725')
# ('403', ': batch_gen_loss : 0.836007, dis_loss :1.2751')
# ('403', ': batch_gen_loss : 0.831606, dis_loss :1.24409')
# ('403', ': batch_gen_loss : 1.04839, dis_loss :1.22238')
# ('403', ': batch_gen_loss : 1.12319, dis_loss :1.19557')
# ('403', ': batch_gen_loss : 0.782493, dis_loss :1.2675')
# ('403', ': batch_gen_loss : 0.952082, dis_loss :1.06466')
# ('403', ': batch_gen_loss : 0.796999, dis_loss :1.31647')
# ('404', ': batch_gen_loss : 0.921257, dis_loss :1.29709')
# ('404', ': batch_gen_loss : 0.927746, dis_loss :1.16789')
# ('404', ': batch_gen_loss : 1.28638, dis_loss :1.32823')
# ('404', ': batch_gen_loss : 0.769781, dis_loss :1.28445')
# ('404', ': batch_gen_loss : 0.846753, dis_loss :1.16873')
# ('404', ': batch_gen_loss : 1.03679, dis_loss :1.26246')
# ('404', ': batch_gen_loss : 1.02305, dis_loss :1.16062')
# ('404', ': batch_gen_loss : 0.974891, dis_loss :1.24386')
# ('404', ': batch_gen_loss : 0.951008, dis_loss :1.16543')
# ('404', ': batch_gen_loss : 0.957355, dis_loss :1.11796')
# Model saved in file : ../gan_model/model.ckpt-405
# ('405', ': batch_gen_loss : 1.05721, dis_loss :1.09053')
# ('405', ': batch_gen_loss : 0.885668, dis_loss :1.31597')
# ('405', ': batch_gen_loss : 0.945606, dis_loss :1.19256')
# ('405', ': batch_gen_loss : 1.0071, dis_loss :1.20177')
# ('405', ': batch_gen_loss : 0.840531, dis_loss :1.23945')
# ('405', ': batch_gen_loss : 1.02502, dis_loss :1.25799')
# ('405', ': batch_gen_loss : 1.14599, dis_loss :0.932328')
# ('405', ': batch_gen_loss : 0.953819, dis_loss :1.24168')
# ('405', ': batch_gen_loss : 0.887511, dis_loss :1.289')
# ('405', ': batch_gen_loss : 0.938272, dis_loss :1.25753')
# ('406', ': batch_gen_loss : 0.864246, dis_loss :1.03767')
# ('406', ': batch_gen_loss : 1.02342, dis_loss :1.18187')
# ('406', ': batch_gen_loss : 0.947625, dis_loss :1.28583')
# ('406', ': batch_gen_loss : 0.817391, dis_loss :1.13714')
# ('406', ': batch_gen_loss : 1.07841, dis_loss :1.13768')
# ('406', ': batch_gen_loss : 1.11538, dis_loss :1.23503')
# ('406', ': batch_gen_loss : 0.911539, dis_loss :1.2136')
# ('406', ': batch_gen_loss : 0.968925, dis_loss :1.15997')
# ('406', ': batch_gen_loss : 0.958206, dis_loss :1.13684')
# ('406', ': batch_gen_loss : 0.900053, dis_loss :1.03359')
# ('407', ': batch_gen_loss : 0.809698, dis_loss :1.31152')
# ('407', ': batch_gen_loss : 0.980819, dis_loss :1.17471')
# ('407', ': batch_gen_loss : 1.10794, dis_loss :1.04605')
# ('407', ': batch_gen_loss : 0.973957, dis_loss :1.06848')
# ('407', ': batch_gen_loss : 0.987663, dis_loss :1.11966')
# ('407', ': batch_gen_loss : 0.820951, dis_loss :1.27837')
# ('407', ': batch_gen_loss : 0.942739, dis_loss :1.18404')
# ('407', ': batch_gen_loss : 0.972837, dis_loss :1.06421')
# ('407', ': batch_gen_loss : 0.856893, dis_loss :1.24805')
# ('407', ': batch_gen_loss : 0.96493, dis_loss :1.08108')
# ('408', ': batch_gen_loss : 0.847937, dis_loss :1.1959')
# ('408', ': batch_gen_loss : 0.933177, dis_loss :1.38577')
# ('408', ': batch_gen_loss : 1.00513, dis_loss :1.21569')
# ('408', ': batch_gen_loss : 0.939852, dis_loss :1.27622')
# ('408', ': batch_gen_loss : 1.00967, dis_loss :1.14914')
# ('408', ': batch_gen_loss : 0.975656, dis_loss :1.24586')
# ('408', ': batch_gen_loss : 1.00936, dis_loss :1.21529')
# ('408', ': batch_gen_loss : 0.93364, dis_loss :1.18786')
# ('408', ': batch_gen_loss : 0.811817, dis_loss :1.10113')
# ('408', ': batch_gen_loss : 1.05265, dis_loss :1.23776')
# ('409', ': batch_gen_loss : 0.882985, dis_loss :1.25277')
# ('409', ': batch_gen_loss : 0.967403, dis_loss :1.24913')
# ('409', ': batch_gen_loss : 0.785238, dis_loss :1.23986')
# ('409', ': batch_gen_loss : 1.08927, dis_loss :1.09943')
# ('409', ': batch_gen_loss : 0.876437, dis_loss :1.33784')
# ('409', ': batch_gen_loss : 0.857415, dis_loss :1.26975')
# ('409', ': batch_gen_loss : 1.08699, dis_loss :1.21188')
# ('409', ': batch_gen_loss : 0.851261, dis_loss :1.25871')
# ('409', ': batch_gen_loss : 0.912048, dis_loss :1.13261')
# ('409', ': batch_gen_loss : 0.88174, dis_loss :1.20668')
# Model saved in file : ../gan_model/model.ckpt-410
# ('410', ': batch_gen_loss : 0.997493, dis_loss :1.36983')
# ('410', ': batch_gen_loss : 0.862736, dis_loss :1.18211')
# ('410', ': batch_gen_loss : 0.923973, dis_loss :1.29602')
# ('410', ': batch_gen_loss : 0.932675, dis_loss :1.2688')
# ('410', ': batch_gen_loss : 0.916197, dis_loss :1.20125')
# ('410', ': batch_gen_loss : 0.936442, dis_loss :1.1922')
# ('410', ': batch_gen_loss : 0.80818, dis_loss :1.25632')
# ('410', ': batch_gen_loss : 0.907976, dis_loss :1.29738')
# ('410', ': batch_gen_loss : 0.779278, dis_loss :1.2225')
# ('410', ': batch_gen_loss : 0.894054, dis_loss :1.17187')
# ('411', ': batch_gen_loss : 0.917768, dis_loss :1.22279')
# ('411', ': batch_gen_loss : 0.789551, dis_loss :1.26908')
# ('411', ': batch_gen_loss : 0.926012, dis_loss :1.26186')
# ('411', ': batch_gen_loss : 0.990253, dis_loss :1.22579')
# ('411', ': batch_gen_loss : 0.983026, dis_loss :1.11554')
# ('411', ': batch_gen_loss : 0.769317, dis_loss :1.33417')
# ('411', ': batch_gen_loss : 0.812166, dis_loss :1.37825')
# ('411', ': batch_gen_loss : 0.911457, dis_loss :1.31285')
# ('411', ': batch_gen_loss : 1.07772, dis_loss :1.12038')
# ('411', ': batch_gen_loss : 0.929575, dis_loss :1.24028')
# ('412', ': batch_gen_loss : 0.907099, dis_loss :1.16615')
# ('412', ': batch_gen_loss : 0.876463, dis_loss :1.18981')
# ('412', ': batch_gen_loss : 0.858208, dis_loss :1.21938')
# ('412', ': batch_gen_loss : 0.88262, dis_loss :1.14741')
# ('412', ': batch_gen_loss : 0.923918, dis_loss :1.17821')
# ('412', ': batch_gen_loss : 1.05339, dis_loss :1.33194')
# ('412', ': batch_gen_loss : 1.05962, dis_loss :1.14441')
# ('412', ': batch_gen_loss : 0.824148, dis_loss :1.14907')
# ('412', ': batch_gen_loss : 0.982504, dis_loss :1.08183')
# ('412', ': batch_gen_loss : 0.846792, dis_loss :0.953301')
# ('413', ': batch_gen_loss : 0.920351, dis_loss :1.25782')
# ('413', ': batch_gen_loss : 0.924012, dis_loss :1.14313')
# ('413', ': batch_gen_loss : 1.20254, dis_loss :1.26196')
# ('413', ': batch_gen_loss : 1.03153, dis_loss :1.06814')
# ('413', ': batch_gen_loss : 0.905825, dis_loss :1.22611')
# ('413', ': batch_gen_loss : 0.9772, dis_loss :1.42177')
# ('413', ': batch_gen_loss : 0.9573, dis_loss :1.1281')
# ('413', ': batch_gen_loss : 0.836819, dis_loss :1.14733')
# ('413', ': batch_gen_loss : 1.03007, dis_loss :1.11944')
# ('413', ': batch_gen_loss : 0.934187, dis_loss :1.1085')
# ('414', ': batch_gen_loss : 1.04307, dis_loss :1.20066')
# ('414', ': batch_gen_loss : 0.857564, dis_loss :1.07858')
# ('414', ': batch_gen_loss : 1.02155, dis_loss :1.21572')
# ('414', ': batch_gen_loss : 0.994727, dis_loss :1.22626')
# ('414', ': batch_gen_loss : 1.08801, dis_loss :1.13935')
# ('414', ': batch_gen_loss : 0.904205, dis_loss :1.05373')
# ('414', ': batch_gen_loss : 0.967837, dis_loss :1.1625')
# ('414', ': batch_gen_loss : 0.977943, dis_loss :1.08834')
# ('414', ': batch_gen_loss : 0.857383, dis_loss :1.22153')
# ('414', ': batch_gen_loss : 0.855847, dis_loss :1.18557')
# Model saved in file : ../gan_model/model.ckpt-415
# ('415', ': batch_gen_loss : 1.07887, dis_loss :1.04391')
# ('415', ': batch_gen_loss : 0.994866, dis_loss :1.04892')
# ('415', ': batch_gen_loss : 0.916284, dis_loss :1.18305')
# ('415', ': batch_gen_loss : 0.992731, dis_loss :1.18553')
# ('415', ': batch_gen_loss : 0.93838, dis_loss :1.12268')
# ('415', ': batch_gen_loss : 1.16402, dis_loss :1.0973')
# ('415', ': batch_gen_loss : 0.979033, dis_loss :1.15642')
# ('415', ': batch_gen_loss : 1.00829, dis_loss :1.07014')
# ('415', ': batch_gen_loss : 0.851689, dis_loss :1.09193')
# ('415', ': batch_gen_loss : 0.887381, dis_loss :1.31448')
# ('416', ': batch_gen_loss : 1.20595, dis_loss :1.03675')
# ('416', ': batch_gen_loss : 0.989452, dis_loss :1.0167')
# ('416', ': batch_gen_loss : 0.858173, dis_loss :1.12859')
# ('416', ': batch_gen_loss : 0.992279, dis_loss :1.12181')
# ('416', ': batch_gen_loss : 1.01696, dis_loss :1.14148')
# ('416', ': batch_gen_loss : 1.00496, dis_loss :1.25375')
# ('416', ': batch_gen_loss : 0.839572, dis_loss :1.36244')
# ('416', ': batch_gen_loss : 0.831515, dis_loss :1.19356')
# ('416', ': batch_gen_loss : 1.17371, dis_loss :1.1859')
# ('416', ': batch_gen_loss : 0.949899, dis_loss :1.22769')
# ('417', ': batch_gen_loss : 1.08956, dis_loss :1.10192')
# ('417', ': batch_gen_loss : 1.09063, dis_loss :1.1659')
# ('417', ': batch_gen_loss : 0.999355, dis_loss :1.21509')
# ('417', ': batch_gen_loss : 0.919893, dis_loss :1.18369')
# ('417', ': batch_gen_loss : 1.0229, dis_loss :1.26751')
# ('417', ': batch_gen_loss : 0.940794, dis_loss :1.21521')
# ('417', ': batch_gen_loss : 0.792846, dis_loss :1.25445')
# ('417', ': batch_gen_loss : 1.19099, dis_loss :1.29864')
# ('417', ': batch_gen_loss : 0.922405, dis_loss :1.1874')
# ('417', ': batch_gen_loss : 0.813038, dis_loss :1.20227')
# ('418', ': batch_gen_loss : 1.03367, dis_loss :1.00184')
# ('418', ': batch_gen_loss : 0.898426, dis_loss :1.26766')
# ('418', ': batch_gen_loss : 0.970303, dis_loss :1.29268')
# ('418', ': batch_gen_loss : 0.845179, dis_loss :1.39749')
# ('418', ': batch_gen_loss : 0.893313, dis_loss :1.282')
# ('418', ': batch_gen_loss : 1.03015, dis_loss :1.14399')
# ('418', ': batch_gen_loss : 0.937432, dis_loss :1.19892')
# ('418', ': batch_gen_loss : 0.821613, dis_loss :1.24655')
# ('418', ': batch_gen_loss : 1.11447, dis_loss :1.22853')
# ('418', ': batch_gen_loss : 1.06327, dis_loss :1.31417')
# ('419', ': batch_gen_loss : 0.957064, dis_loss :1.00832')
# ('419', ': batch_gen_loss : 0.938869, dis_loss :1.22006')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-aad933715bf3> in <module>()
#      42                               restore_step=200
#      43                               )
# ---> 44 train_module.train()
#
# /home/hyem/PycharmProjects/git/Text2Action/model/trainer_GAN.pyc in train(self)
#     127                                                        self.ph_action: np.transpose(action_batch, [0, 2, 1]),
#     128                                                        self.ph_action_fake: np.transpose(np.stack(curr_fake), [1, 0, 2]),
# --> 129                                                        self.ph_num_data: self.batch_size
#     130                                                        })
#     131
#
# /home/hyem/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/hyem/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /home/hyem/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /home/hyem/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /home/hyem/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
